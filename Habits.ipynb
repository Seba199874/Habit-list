# %%
import json
from datetime import date 
Data_FILE ="Habits.data.json"

# %%
DEFAULT_Task = [
    {"id": 1, "name": "Drink at least 8 cups of water"},
    {"id": 2, "name": "Go to the gym or do 30 minutes of exercise"},
    {"id": 3, "name": "Sleep at least 8 hours"},
    {"id": 4, "name": "Spend 10 minutes in prayer/Bible time"},
    {"id": 5, "name": "Do at leats 1 hour of homework/study"},
]

# %%
def load_data():
    try:
        with open(DATA_FILE,"r") as f:
            return json.load(f)
    except (FileNotFoundError, json.JSONDecodeError):
        return {}

# %%
def save_data(data):
    with open(DATA_FILE, "w") as f:
        json.dump(data, f, indent=2)

# %%
def ask_yes_no(prompt):
    while True:
        answer = input(promt + " (y/n): ").strip().lower()
        if answer in ("y", "yes"):
            return True
        if answer in ("n", "no"):
            return False
        print("Please type 'y' or 'n'.")

# %%
def run_for_today():
    today_str = str(date.today())
    print("=== Daily Habit Scorecard ===")
    print("Date:", today_str)
    print()
    completed = []
    for task in DEFAULT_TASKS:
        print(f"{task['id']}. {task['name']}")
        done = ask_yes_no("Did you complete this today?")
        completed.append({
        "id": task["id"],
        "name": task["name"],
        "done": done
        })
        print()
    total = len(completed)
    done_count = sum(1 for t in completed if t["done"])
    percent = round(done_count / total * 100)

    if percent == 100:
        message = "Awesome job! Let's goooooo!!."
    elif percent >= 60:
        message = " Nice work . But we can push Harder."
    elif percent > 0:
        message = " Bro, lock in what are you doing?."
    else:
        message = " You need to start working harder"

    print("=== Today's Results ===")
    print(f"Habits completed: {done_count} / {total}")
    print(f"Daily score: {percent}%")
    print(message)

    data = load_data()
    data[today_str] = {
        "completed": completed,
        "score": percent,
        "done_count": done_count,
        "total": total
    }
    save_data(data)

    if ask_yes_no("Do you want to see past scores?"):
        print("\n=== Past Days ===")
        for day, info in sorted(data.items()):
            print(f"{day}: {info['score']}% ({info['done_count']}/{info['total']})")

if __name__ == "__main__":
    run_for_today()
# Out:
# === Daily Habit Scorecard ===
# Date: 2025-11-24
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 49
#      46             print(f"{day}: {info['score']}% ({info['done_count']}/{info['total']})")
#      48 if __name__ == "__main__":
# ---> 49     run_for_today()
#
# Cell In[28], line 7, in run_for_today()
#       5 print()
#       6 completed = []
# ----> 7 for task in DEFAULT_TASKS:
#       8     print(f"{task['id']}. {task['name']}")
#       9     done = ask_yes_no("Did you complete this today?")
#
# NameError: name 'DEFAULT_TASKS' is not defined

# %%
import json
from datetime import date 
Data_FILE ="Habits.data.json"

DEFAULT_Task = [
    {"id": 1, "name": "Drink at least 8 cups of water"},
    {"id": 2, "name": "Go to the gym or do 30 minutes of exercise"},
    {"id": 3, "name": "Sleep at least 8 hours"},
    {"id": 4, "name": "Spend 10 minutes in prayer/Bible time"},
    {"id": 5, "name": "Do at least 1 hour of homework/study"},
]

def load_data():
    try:
        with open(DATA_FILE,"r") as f:
            return json.load(f)
    except (FileNotFoundError, json.JSONDecodeError):
        return {} 
def save_data(data):
    with open(DATA_FILE, "w") as f:
        json.dump(data, f, indent=2)
def ask_yes_no(prompt):
    while True:
        answer = input(promt + " (y/n): ").strip().lower()
        if answer in ("y", "yes"):
            return True
        if answer in ("n", "no"):
            return False
        print("Please type 'y' or 'n'.")

def run_for_today():
    today_str = str(date.today())
    print("=== Daily Habit Scorecard ===")
    print("Date:", today_str)
    print()
    completed = []
    for task in DEFAULT_TASKS:
        print(f"{task['id']}. {task['name']}")
        done = ask_yes_no("Did you complete this today?")
        completed.append({
        "id": task["id"],
        "name": task["name"],
        "done": done
        })
        print()
    total = len(completed)
    done_count = sum(1 for t in completed if t["done"])
    percent = round(done_count / total * 100)

    if percent == 100:
        message = "Awesome job! Let's goooooo!!."
    elif percent >= 60:
        message = " Nice work . But we can push Harder."
    elif percent > 0:
        message = " Bro, lock in what are you doing?."
    else:
        message = " You need to start working harder"

    print("=== Today's Results ===")
    print(f"Habits completed: {done_count} / {total}")
    print(f"Daily score: {percent}%")
    print(message)

    data = load_data()
    data[today_str] = {
        "completed": completed,
        "score": percent,
        "done_count": done_count,
        "total": total
    }
    save_data(data)

    if ask_yes_no("Do you want to see past scores?"):
        print("\n=== Past Days ===")
        for day, info in sorted(data.items()):
            print(f"{day}: {info['score']}% ({info['done_count']}/{info['total']})")

if __name__ == "__main__":
    run_for_today()
# Out:
# === Daily Habit Scorecard ===
# Date: 2025-11-24
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 79
#      76             print(f"{day}: {info['score']}% ({info['done_count']}/{info['total']})")
#      78 if __name__ == "__main__":
# ---> 79     run_for_today()
#
# Cell In[29], line 37, in run_for_today()
#      35 print()
#      36 completed = []
# ---> 37 for task in DEFAULT_TASKS:
#      38     print(f"{task['id']}. {task['name']}")
#      39     done = ask_yes_no("Did you complete this today?")
#
# NameError: name 'DEFAULT_TASKS' is not defined

# %%
import json
from datetime import date

DATA_FILE = "Habits_data.json"

DEFAULT_TASKS = [
    {"id": 1, "name": "Drink at least 8 cups of water"},
    {"id": 2, "name": "Go to the gym or do 30 minutes of exercise"},
    {"id": 3, "name": "Sleep at least 8 hours"},
    {"id": 4, "name": "Spend 10 minutes in prayer/Bible time"},
    {"id": 5, "name": "Do at least 1 hour of homework/study"},
]

def load_data():
    try:
        with open(DATA_FILE, "r") as f:
            return json.load(f)
    except (FileNotFoundError, json.JSONDecodeError):
        return {}

def save_data(data):
    with open(DATA_FILE, "w") as f:
        json.dump(data, f, indent=2)

def ask_yes_no(prompt):
    while True:
        answer = input(prompt + " (y/n): ").strip().lower()
        if answer in ("y", "yes"):
            return True
        if answer in ("n", "no"):
            return False
        print("Please type 'y' or 'n'.")

def run_for_today():
    today_str = str(date.today())
    print("=== Daily Habit Scorecard ===")
    print("Date:", today_str)
    print()

    completed = []
    for task in DEFAULT_TASKS:
        print(f"{task['id']}. {task['name']}")
        done = ask_yes_no("Did you complete this today?")
        completed.append({
            "id": task["id"],
            "name": task["name"],
            "done": done
        })
        print()

    total = len(completed)
    done_count = sum(1 for t in completed if t["done"])
    percent = round(done_count / total * 100)

    if percent == 100:
        message = "Awesome job! Let's goooooo!!"
    elif percent >= 60:
        message = "Nice work. But we can push harder."
    elif percent > 0:
        message = "Bro, lock in. What are you doing?"
    else:
        message = "You need to start working harder."

    print("=== Today's Results ===")
    print(f"Habits completed: {done_count} / {total}")
    print(f"Daily score: {percent}%")
    print(message)

    data = load_data()
    data[today_str] = {
        "completed": completed,
        "score": percent,
        "done_count": done_count,
        "total": total
    }
    save_data(data)

    if ask_yes_no("Do you want to see past scores?"):
        print("\n=== Past Days ===")
        for day, info in sorted(data.items()):
            print(f"{day}: {info['score']}% ({info['done_count']}/{info['total']})")


run_for_today()
# Out:
# === Daily Habit Scorecard ===
# Date: 2025-11-24
#
# 1. Drink at least 8 cups of water
# Did you complete this today? (y/n):  y
# 2. Go to the gym or do 30 minutes of exercise
# Did you complete this today? (y/n):  n
# 3. Sleep at least 8 hours
# Did you complete this today? (y/n):  y
# 4. Spend 10 minutes in prayer/Bible time
# Did you complete this today? (y/n):  y
# 5. Do at least 1 hour of homework/study
# Did you complete this today? (y/n):  y
# === Today's Results ===
# Habits completed: 4 / 5
# Daily score: 80%
# Nice work. But we can push harder.
# Do you want to see past scores? (y/n):  y
# === Past Days ===
# 2025-11-24: 80% (4/5)
